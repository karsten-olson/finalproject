# %%
import pandas as pd

# %%
data = "new_nba_dataset.csv"

# %%
data_pd = pd.read_csv(data)
data_pd.head()
# Out:
#    Unnamed: 0 Team  Game        Date  Home Opponent WINorLOSS  \
# 0        1306  BOS     1  10/17/2017  Away      CLE         L
# 1        2306  BOS     2  10/18/2017  Home      MIL         L
# 2        3306  BOS     3  10/20/2017  Away      PHI         W
# 3        4306  BOS     4  10/24/2017  Home      NYK         W
# 4        5306  BOS     5  10/26/2017  Away      MIL         W
#
#    OPTotalNumberPossession  OPOffensiveRating  OPDefensiveRating  ...  \
# 0                    101.0             100.99              98.02  ...
# 1                     97.0             111.34             103.09  ...
# 2                    100.4              91.63             101.59  ...
# 3                     98.0              90.82             112.24  ...
# 4                     96.6              92.13              99.38  ...
#
#    Opp.FreeThrows  Opp.FreeThrowsAttempted  Opp.FreeThrows.  Opp.OffRebounds  \
# 0              21                       25            0.840                9
# ...

# %%
pd_new = data_pd.drop(columns=['X3PointShots', 'X3PointShotsAttempted', 'X3PointShots.', 'FreeThrows','FreeThrowsAttempted',
                              'FreeThrows.', 'OffRebounds', 'TotalRebounds','Assists','Steals', 'Blocks', 'Turnovers',
                              'TotalFouls','Opp.FieldGoals', 'Opp.FieldGoalsAttempted', 'Opp.FieldGoals.', 'Opp.3PointShots',
                              'Opp.3PointShotsAttempted', 'Opp.3PointShots.', 'TeamPoints', 'OpponentPoints', 'FieldGoals','FieldGoalsAttempted', 'FieldGoals.',
                              'Opp.FreeThrows', 'Opp.FreeThrowsAttempted', 'Opp.FreeThrows.', 'Opp.OffRebounds',
                              'Opp.TotalRebounds', 'Opp.TotalRebounds', 'Opp.Assists', 'Opp.Steals', 'Opp.Blocks',
                              'Opp.Turnovers', 'Opp.TotalFouls', 'Unnamed: 0', 'Game', 'Date', 'Opponent', 'WINorLOSS', 'Home'])

# %%
pd_new
# Out:
#     Team  OPTotalNumberPossession  OPOffensiveRating  OPDefensiveRating  \
# 0    BOS                    101.0             100.99              98.02
# 1    BOS                     97.0             111.34             103.09
# 2    BOS                    100.4              91.63             101.59
# 3    BOS                     98.0              90.82             112.24
# 4    BOS                     96.6              92.13              99.38
# ..   ...                      ...                ...                ...
# 651  UTA                     97.4             112.94             120.12
# 652  UTA                     95.2              99.79             122.90
# 653  UTA                    101.8              95.28             110.02
# 654  UTA                     98.4              80.28             120.93
# 655  UTA                     98.4             103.66              94.51
#
#      OPPDelta  FavDelta  defensiverating  TotalNumberPossession  \
# ...

# %%
bos_pd = pd_new.loc[pd_new['Team'] == 'BOS']
cle_pd = pd_new.loc[pd_new['Team'] == 'CLE']
gsw_pd = pd_new.loc[pd_new['Team'] == 'GSW']
hou_pd = pd_new.loc[pd_new['Team'] == 'HOU']
nop_pd = pd_new.loc[pd_new['Team'] == 'NOP']
phi_pd = pd_new.loc[pd_new['Team'] == 'PHI']
tor_pd = pd_new.loc[pd_new['Team'] == 'TOR']
uta_pd = pd_new.loc[pd_new['Team'] == 'UTA']

# %%
gsw_pd.head()
# Out:
#     Team  OPTotalNumberPossession  OPOffensiveRating  OPDefensiveRating  \
# 492  TOR                    105.6              94.70             110.80
# 493  TOR                    108.4              86.72             118.08
# 494  TOR                    101.2              99.80              95.85
# 495  TOR                     96.8             120.87             115.70
# 496  TOR                    100.6              91.45             100.40
#
#      OPPDelta  FavDelta  defensiverating  TotalNumberPossession  \
# 492    -16.10     20.94            98.20                   98.2
# 493    -31.37      1.90           115.74                  108.8
# 494      3.95      0.75            97.62                   98.6
# 495      5.17     25.35            85.98                  100.6
# 496     -8.95    -15.93           113.04                  104.0
#
#      offensiverating
# 492           119.14
# 493           117.65
# 494            98.38
# 495           111.33
# 496            97.12

# %%
 # %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

# %%
X = cle_pd.TotalNumberPossession.values.reshape(-1, 1)
y = cle_pd.FavDelta.values.reshape(-1, 1)

print("Shape: ", X.shape, y.shape)
X
# Out:
# Shape:  (82, 1) (82, 1)
# array([[101. ],
#        [ 95.8],
#        [101.8],
#        [ 92.8],
#        [103.4],
#        [100.2],
#        [ 99.8],
#        [102. ],
#        [ 99.2],
#        [103.2],
#        [ 97.2],
#        [100.6],
#        [102. ],
#        [102.8],
#        [100. ],
#        [108.6],
#        [ 90.8],
#        [ 98.8],
#        [ 98. ],
#        [ 94. ],
#        [ 98.2],
#        [ 96.8],
#        [ 93.2],
#        [ 89.8],
#        [ 94.4],
#        [ 95.8],
#        [ 96. ],
#        [ 97. ],
#        [102. ],
#        [ 89.8],
#        [ 95.8],
#        [ 96.6],
#        [ 95.8],
#        [ 93. ],
#        [ 88. ],
#        [ 97.4],
#        [ 99.8],
#        [101.2],
#        [109.4],
#        [ 95.4],
#        [101. ],
#        [ 94.6],
#        [105.8],
#        [101.8],
#        [111.8],
#        [ 96.4],
#        [ 99.2],
#        [ 99.4],
#        [104.8],
#        [104.2],
#        [ 99.4],
#        [ 97. ],
#        [105.2],
#        [ 98.6],
# ...

# %%
plt.scatter(X, y)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()

# %%
model.fit(X, y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
print('Weight coefficients: ', model.coef_)
print('y-axis intercept: ', model.intercept_)
# Out:
# Weight coefficients:  [[-0.6311478]]
# y-axis intercept:  [83.73713261]

# %%
x_min = np.array([[X.min()]])
x_max = np.array([[X.max()]])
print(f"Min X Value: {x_min}")
print(f"Max X Value: {x_max}")
# Out:
# Min X Value: [[88.]]
# Max X Value: [[113.]]

# %%
y_min = model.predict(x_min)
y_max = model.predict(x_max)

# %%
plt.scatter(X, y, c='Maroon')
plt.plot([x_min[0], x_max[0]], [y_min[0], y_max[0]], c='red')
plt.xlabel("Finals Total Number Possession")
plt.ylabel("Finals Net Rating")
plt.axvline(x= 93.3)
plt.savefig("Data Fig/CLE_Finals_Net_PPP.png")
